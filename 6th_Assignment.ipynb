# %% [markdown]
# Q1. Ask the user to enter a value (e.g., M) for a mathematical function.
#  Generate x values from -10 to 10 using np.linspace().
#  Compute y values for:
# o y= M⋅x
# 2
# o y=M⋅sin(x)
#  Plot both functions in a single figure:
# o Use different colors and line styles.
# o Add legend, grid, and title.

# %%
import numpy as np
import matplotlib.pyplot as plt

M = float(input("Enter the value for M: "))

x = np.linspace(-10, 10, 400)

y1 = M * x**2
y2 = M * np.sin(x)

plt.plot(x, y1, label=r'$y = M \cdot x^2$', color='pink', linestyle='-', linewidth=2)
plt.plot(x, y2, label=r'$y = M \cdot sin(x)$', color='purple', linestyle='--', linewidth=2)

# Adding title, grid, legend
plt.title('Plot of y = M*x^2 and y = M*sin(x)', fontsize=14)
plt.xlabel('x values', fontsize=12)
plt.ylabel('y values', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter the value for M:  10

# %% [markdown]
# Q.2 Create a dataset of five subjects and scores.
#  Convert it into a Pandas DataFrame.
#  Plot the scores using a Seaborn bar plot with:
# o Different colors for each bar.
# o Annotations on top of each bar.
# o Title, axis labels, and grid.

# %%
import pandas as pd
import seaborn as sns

data = {'Subject': ['Math', 'Science', 'English', 'History', 'Geography'],
        'Score': [88, 92, 79, 85, 90]}

df = pd.DataFrame(data)

sns.barplot(x='Subject', y='Score', data=df, palette='Set2')

for index, value in enumerate(df['Score']):
    plt.text(index, value + 1, str(value), ha='center', va='bottom')

plt.title('Scores for Different Subjects', fontsize=14)
plt.xlabel('Subjects', fontsize=12)
plt.ylabel('Scores', fontsize=12)

plt.show()

# %% [markdown]
# Q3. Write a Python script to select your roll number as seed for NumPy and
# then generate a dataset of 50 values using np.random.randn()
# > Create a 2 x 2 subplot layout displaying:
# o Line plot showing cumulative sum.
# o Scatter plot with random noise.
# > Customize with titles, axis labels, and grids.

# %%
seed_val = 102497006
np.random.seed(seed_val)

data_vals = np.random.randn(50)
cumulative_vals = np.cumsum(data_vals)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].plot(cumulative_vals, 'g-', linewidth=2)
axes[0].set_title("Cumulative Sum Plot")
axes[0].set_xlabel("Index")
axes[0].set_ylabel("Cumulative Sum")
axes[0].grid(True)

axes[1].scatter(range(50), data_vals, c='r', marker='o')
axes[1].set_title("Scatter Plot with Random Noise")
axes[1].set_xlabel("Index")
axes[1].set_ylabel("Value")
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Q.4 Download Data-set from the below link
# https://github.com/AnjulaMehto/MCA/blob/main/company_sales_data.csv
# Apply ‘seaborn’ library to do the following.
# 1. Read Total profit of all months and show it using a line plot.
# 2. Read all product sales data and show it using a multiline plot.
# 3. Plot bar chart for all the features/attributes.

# %%
df = pd.read_csv("company_sales_data.csv")

plt.figure(figsize=(10, 5))
sns.lineplot(x=df["month_number"], y=df["total_profit"], marker="o", label="Total Profit", color="pink")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("1) Total Profit Per Month")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
for column in df.columns[1:-1]:  # Excluding 'month_number' and 'total_profit'
    sns.lineplot(x=df["month_number"], y=df[column], marker="o", label=column)
plt.xlabel("Month Number")
plt.ylabel("Sales")
plt.title("2) Sales of Different Products Per Month")
plt.legend()
plt.grid(True)
plt.show()

df.set_index("month_number").plot(kind="bar", figsize=(15, 6))
plt.xlabel("Month Number")
plt.ylabel("Values")
plt.title("3) Bar Chart of All Features")
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid(axis="y", linestyle="--")
plt.show()
# Out:
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\CSED\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
