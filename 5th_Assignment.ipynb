# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
# i. Sum of all elements
# ii. Sum of all elements row-wise
# iii. Sum of all elements column-wise

# %%
#Q.1
import numpy as np
gfg=np.matrix('[4,1,9;12,3,1;4,5,6]')
sum_all_elements=np.sum(gfg)
print("sum of all elements:",sum_all_elements)

row_sum=np.sum(gfg, axis=1)
print("sum of all elements row wise:",row_sum)

column_sum=np.sum(gfg, axis=0)
print("sum of all elements column wise:",column_sum)
# Out:
# sum of all elements: 45
# sum of all elements row wise: [[14]
#  [16]
#  [15]]
# sum of all elements column wise: [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
# i. Sorted array
# ii. Indices of sorted array
# iii. 4 smallest elements
# iv. 5 largest elements

# %%
#Q.2(a)
array_a=np.array([10,52,62,16,16,54,453])
sorted_array=np.sort(array_a)
print("sorted array:",sorted_array)

sorted_indices=np.argsort(array_a)
print("Indices of sorted array:",sorted_indices)

four_smallest_elements=np.sort(array_a)[:4]
print("The four smallest elements are:",four_smallest_elements)

five_largest_elements=np.sort(array_a)[-5:]
print("The five largest elements are:",five_largest_elements)
# Out:
# sorted array: [ 10  16  16  52  54  62 453]
# Indices of sorted array: [0 3 4 1 5 2 6]
# The four smallest elements are: [10 16 16 52]
# The five largest elements are: [ 16  52  54  62 453]

# %% [markdown]
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
# i. Integer elements only
# ii. Float elements only

# %%
#Q.2(b)
array_b=np.array([1.0,1.2,2.2,2.0,3.0,2.0])

integer_elements=array_b[array_b==array_b.astype(int)]
print("Integer elements only:",integer_elements)

float_elements=array_b[array_b!=array_b.astype(int)]
print("Float elements only:",float_elements)
# Out:
# Integer elements only: [1. 2. 3. 2.]
# Float elements only: [1.2 2.2]

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
# a) Generate your unique sales dataset:
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
#
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#  Use broadcasting to apply this tax rate to each sales value.
# c) Adjust sales based on discount:
#  If sales < X+100, apply a 5% discount.
#  If sales >= X+100, apply a 10% discount.
# d) Expand sales data for multiple weeks:
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
#Q.3
import numpy as np


initials = ['S', 'S']
ascii_sum = sum(ord(ch) for ch in initials)
X = ascii_sum


sales = np.array([X, X + 50, X + 100, X + 150, X + 200])
print("Sales dataset:", sales)


tax_rate = ((X % 5) + 5) / 100
print("Personalized tax rate:", tax_rate)


sales_after_tax = sales * (1 + tax_rate)
print("Sales after tax:", sales_after_tax)


discounted_sales = np.where(sales < X + 100, sales * 0.95, sales * 0.90)
print("Discounted sales:", discounted_sales)


weekly_sales = np.tile(sales, (3, 1))
print("Weekly sales data (initial):\n", weekly_sales)


weeks = np.arange(3).reshape(-1, 1)  
weekly_sales = weekly_sales * (1 + 0.02 * weeks)
print("Weekly sales data (after 2% increase per week):\n", weekly_sales)
# Out:
# Sales dataset: [166 216 266 316 366]
# Personalized tax rate: 0.06
# Sales after tax: [175.96 228.96 281.96 334.96 387.96]
# Discounted sales: [157.7 205.2 239.4 284.4 329.4]
# Weekly sales data (initial):
#  [[166 216 266 316 366]
#  [166 216 266 316 366]
#  [166 216 266 316 366]]
# Weekly sales data (after 2% increase per week):
#  [[166.   216.   266.   316.   366.  ]
#  [169.32 220.32 271.32 322.32 373.32]
#  [172.64 224.64 276.64 328.64 380.64]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#  Y = x2
#  Y = sin(x)
#  Y = ex
#  Y = log(|x| + 1)
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(-10, 10, 100)

# Compute y values for each function
y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)

# Plot the functions
plt.figure(figsize=(12, 10))

# Y = x^2
plt.subplot(2, 2, 1)
plt.plot(x, y1, label='y = x^2',color='g')
plt.title('y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# Y = sin(x)
plt.subplot(2, 2, 2)
plt.plot(x, y2, label='y = sin(x)',color='pink')
plt.title('y = sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# Y = exp(x)
plt.subplot(2, 2, 3)
plt.plot(x, y3, label='y = exp(x)',color='r')
plt.title('y = exp(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# Y = log(|x| + 1)
plt.subplot(2, 2, 4)
plt.plot(x, y4, label='y = log(|x| + 1)',color='b')
plt.title('y = log(|x| + 1)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
